# %% [markdown]
# # 01 — Exploratory data analysis
#
# Planned analysis:
# - Decade distribution across the LOC dataset
# - Image quality and resolution checks
# - Sample images per decade
#
# Run after collecting data with `python src/scraper.py`.
