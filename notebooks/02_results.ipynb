# %% [markdown]
# # 02 — Evaluation results & Grad-CAM findings
#
# Planned content:
# - Confusion matrix and per-decade F1
# - Mean decade error
# - Grad-CAM heatmaps with qualitative historical analysis
#
# Run after training and evaluation complete.
